# %% [markdown]
# ### Aula 1: Exercícios
#
# Para estes exercícios, iremos utilizar duas bases:
#
# 1) base fictícia de funcionários criada por cientistas de dados da IBM.
#
# **Variáveis:**
# - **Age:** Idade
# - **Attrition:** Se saiu da empresa (Sim ou não)
# - **BusinessTravel:** Frequência de viagens a trabalho
# - **DailyRate:** Custo do funcionário por dia
# - **Department:** Departamento
# - **DistanceFromHome:** Distância do trabalho até a casa do funcionário
# - **Education:** Nível de educação:
#     - 1: 'Below College'
#     - 2: 'College'
#     - 3: 'Bachelor'
#     - 4: 'Master'
#     - 5: 'Doctor'
# - **EducationField:** Área da educação
# - **EmployeeNumber:** ID do funcionário
# - **EnvironmentSatisfaction:** Satisfação com o ambiente de trabalho:
#     - 1: 'Low'
#     - 2: 'Medium'
#     - 3: 'High'
#     - 4: 'Very High'
# - **Gender:** Gênero
# - **HourlyRate:** Valor/hora
# - **JobInvolvement:** Nível de envolvimento com o trabalho (psicologica e emocionalmente):
#     - 1: 'Low'
#     - 2: 'Medium'
#     - 3: 'High'
#     - 4: 'Very High'
# - **JobLevel:** Nível do funcionário
# - **JobRole:** Cargo
# - **JobSatisfaction:** Nível de satisfação com o trabalho:
#     - 1: 'Low'
#     - 2: 'Medium'
#     - 3: 'High'
#     - 4: 'Very High'
# - **MaritalStatus:** Estado Civil
# - **NumCompaniesWorked:** Número de empresas que já trabalhou
# - **PercentSalaryHike:** Aumento salarial (%)
# - **PerformanceRating:** Nível de performance:
#     - 1: 'Low'
#     - 2: 'Good'
#     - 3: 'Excellent'
#     - 4: 'Outstanding'
# - **RelationshipSatisfaction:** Satisfação de relacionamento:
#     - 1: 'Low'
#     - 2: 'Medium'
#     - 3: 'High'
#     - 4: 'Very High'
# - **TotalWorkingYears:** Número de anos trabalhados
# - **TrainingTimesLastYear:** Número de treinamentos no ano anterior
# - **WorkLifeBalance:** Equilíbrio da vida profissional
#     - 1: 'Bad'
#     - 2: 'Good'
#     - 3: 'Better'
#     - 4: 'Best'
# - **YearsAtCompany:** Anos na empresa
# - **YearsInCurrentRole:** Anos na posição atual
# - **YearsSinceLastPromotion:** Anos desde a última promoção
# - **YearsWithCurrManager:** Anos com o mesmo gestor
#
# 2) Base de dados de casos e óbitos de covid no estado de SP.
#
# - **nome_munic:** Nome do município
# - **codigo_ibge:** Código do município no IBGE (7 dígitos)
# - **casos_novos:** Casos novos registrados na data
# - **obitos_novos:** Óbitos novos registrados na data
# - **nome_drs:** Nome do Dpto. Regional de Saúde
# - **cod_drs:** Código do Dpto. Regional de Saúde
# - **pop:** População Estimada (fonte: SEADE)
# - **pop60:** População acima de 60 anos (fonte: SEADE)
# - **ano_mes:** Ano e mês dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df1 = pd.read_csv('IBM_Employees.csv')

# %%
df2 = pd.read_csv('dados_covid_sp_20.csv')

# %% [markdown]
# ## Exercício 1:
# Utilizando a base de dados da IBM e a biblioteca plotly:
#
# **a)** Faça um gráfico de dispersão (scatter plot) de tamanho (10,5), com a variável *YearsAtCompany* no eixo X e a variável *DailyRate* no eixo Y. Coloque o título "YearsAtCompany x DailyRate" na cor azul e com uma letra diferente da usual.

# %%
px.scatter(x='YearsAtCompany', y='DailyRate', data_frame=df1)

fig = px.scatter(x='YearsAtCompany',y='DailyRate',data_frame=df1, title='Gasto Diário por Anos na Empresa')
# falta STATSMODEL para fazer trendlines?

fig.show()
# Out:
# <div>                            <div id="9e4a6774-00aa-4954-818e-d9d4ca1060a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e4a6774-00aa-4954-818e-d9d4ca1060a6")) {                    Plotly.newPlot(                        "9e4a6774-00aa-4954-818e-d9d4ca1060a6",                        [{"hovertemplate":"YearsAtCompany=%{x}<br>DailyRate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[6,10,0,8,2,7,1,1,9,7,5,9,5,2,4,10,6,1,25,3,4,5,12,0,4,14,10,9,22,2,1,4,10,1,2,5,3,2,1,5,1,1,1,9,12,22,9,1,9,1,1,2,4,4,2,15,9,2,7,7,9,10,27,21,17,5,6,1,3,1,4,5,1,10,1,11,15,0,5,4,10,6,1,13,5,6,0,4,11,9,22,10,11,10,11,4,3,5,37,3,3,1,1,16,1,3,8,6,2,0,13,9,5,5,1,5,11,9,1,25,10,7,5,20
# ...

# %% [markdown]
# **b)** Repita o gráfico do item a, identificando as observações do gênero feminino com a cor vermelha e do gênero masculino com a cor verde. Não esqueça de inserir legenda para as cores.

# %%
fig = px.scatter(x='YearsAtCompany',y='DailyRate',data_frame=df1, title='Gasto Diário por Anos na Empresa',
                 color='Gender', symbol='Gender')

fig.update_layout(legend=dict(title='Gênero:', orientation='h', y=0.9, x=0.7, xanchor='left', yanchor='bottom'))

fig.show()
# Out:
# <div>                            <div id="75ba69e3-fbc0-432f-88ed-96bf421bd668" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75ba69e3-fbc0-432f-88ed-96bf421bd668")) {                    Plotly.newPlot(                        "75ba69e3-fbc0-432f-88ed-96bf421bd668",                        [{"hovertemplate":"Gender=Female<br>YearsAtCompany=%{x}<br>DailyRate=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Female","showlegend":true,"x":[6,8,1,9,10,25,4,12,14,10,22,2,5,2,1,5,1,12,22,4,2,15,2,10,27,21,17,5,4,1,11,13,11,4,3,1,16,3,8,0,13,5,1,11,9,1,5,5,40,15,3,2,2,8,15,5,3,5,3,1,20,9,1,4,5,10,8,0,5,2,24,2,4,3,4,4,8,20,7,7,6,5,10,8,7,5,1,6,19,6,3,11,10,2,7,17,9,4,3,2,3,19,3,4,9,7,5,7,8,6,
# ...

# %% [markdown]
# **c)** Repita o gráfico do item a, porém agora identificando os funcionários pela variável 'JobSatisfaction',
# utilizando a seguinte escala de cores:
# - cor: '#FFE4E1' para 'Low'
# - cor: '#FFB6C1' para 'Medium'
# - cor: '#FF69B4' para 'High'
# - cor: '#C71585' para 'Very High'

# %%
fig = px.scatter(x='YearsAtCompany',y='DailyRate',data_frame=df1, title='Gasto Diário por Anos na Empresa')
                 #color='JobSatisfaction') # como aplicar um mapa aqui, se já são números?

#fig.update_layout(legend=dict(title='Satisfação no Trabalho:', orientation='h', y=0.9, x=0.7, xanchor='left', yanchor='top'))
???
fig.show()
# Out:
# <div>                            <div id="09f7f1ca-f8c3-4950-8552-84c8fe732884" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09f7f1ca-f8c3-4950-8552-84c8fe732884")) {                    Plotly.newPlot(                        "09f7f1ca-f8c3-4950-8552-84c8fe732884",                        [{"hovertemplate":"YearsAtCompany=%{x}<br>DailyRate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[6,10,0,8,2,7,1,1,9,7,5,9,5,2,4,10,6,1,25,3,4,5,12,0,4,14,10,9,22,2,1,4,10,1,2,5,3,2,1,5,1,1,1,9,12,22,9,1,9,1,1,2,4,4,2,15,9,2,7,7,9,10,27,21,17,5,6,1,3,1,4,5,1,10,1,11,15,0,5,4,10,6,1,13,5,6,0,4,11,9,22,10,11,10,11,4,3,5,37,3,3,1,1,16,1,3,8,6,2,0,13,9,5,5,1,5,11,9,1,25,10,7,5,20
# ...

# %% [markdown]
# ## Exercício 2
#
# **a)** Utilizando a base de dados de covid e a biblioteca plotly, crie um gráfico de linhas mostrando a evolução do número de casos novos mês a mês, para as DRS 'Grande São Paulo', 'São José do Rio Preto' e 'Marília'. Identifique os DRS por cores e legenda. Não esqueça de colocar título para o gráfico e para os eixos.

# %%
df2_3_drs = df2[['ano_mes','nome_drs','casos_novos']][(df2['nome_drs'] == 'Campinas') | (df2['nome_drs'] == 'São José do Rio Preto'
                                              ) | (df2['nome_drs'] == 'Marília')]

# %%
df2_aux = df2_3_drs.groupby(by = ['ano_mes','nome_drs'], as_index=False).sum()

# %%
df2_aux = df2_3_drs_sort_anomes.pivot_table(index='ano_mes', columns='nome_drs', values='casos_novos', aggfunc='sum')

# %%
df2_aux
# Out:
#     ano_mes               nome_drs  casos_novos
# 0   2020-02               Campinas            0
# 1   2020-02                Marília            0
# 2   2020-02  São José do Rio Preto            0
# 3   2020-03               Campinas           27
# 4   2020-03                Marília            0
# 5   2020-03  São José do Rio Preto            7
# 6   2020-04               Campinas          927
# 7   2020-04                Marília           82
# 8   2020-04  São José do Rio Preto          178
# 9   2020-05               Campinas         4041
# 10  2020-05                Marília          363
# 11  2020-05  São José do Rio Preto         1241
# 12  2020-06               Campinas          952
# 13  2020-06                Marília           64
# 14  2020-06  São José do Rio Preto          148

# %%
df2_aux.index
# Out:
# Index(['2020-02', '2020-03', '2020-04', '2020-05', '2020-06'], dtype='object', name='ano_mes')

# %%
df2_aux.values[1:6]
# Out:
# array([[ 2186,     0,     7],
#        [22094,    82,   178],
#        [60332,   363,  1241],
#        [ 9631,    64,   148]], dtype=int64)

# %%
fig = px.line(x='ano_mes', y='casos_novos', data_frame=df2_aux, color='nome_drs',
       symbol='nome_drs')

fig.update_layout(legend=dict(title='DRS'))

fig.show()
# Out:
# <div>                            <div id="5e94dcb8-d21f-4fa9-b9d3-5b106d94de56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e94dcb8-d21f-4fa9-b9d3-5b106d94de56")) {                    Plotly.newPlot(                        "5e94dcb8-d21f-4fa9-b9d3-5b106d94de56",                        [{"hovertemplate":"nome_drs=Campinas<br>ano_mes=%{x}<br>casos_novos=%{y}<extra></extra>","legendgroup":"Campinas","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Campinas","orientation":"v","showlegend":true,"x":["2020-02","2020-03","2020-04","2020-05","2020-06"],"xaxis":"x","y":[0,27,927,4041,952],"yaxis":"y","type":"scatter"},{"hovertemplate":"nome_drs=Mar\u00edlia<br>ano_mes=%{x}<br>casos_novos=%{y}<extra></
# ...

# %% [markdown]
# **b)** Repita o gráfico do item a trocando as cores dos DRS.

# %%
fig = px.line(x='ano_mes', y='casos_novos', data_frame=df2_aux, color='nome_drs',
       symbol='nome_drs', color_discrete_map={'Campinas':'yellow','São José do Rio Preto':'orange','Marília':'pink'})

fig.update_layout(legend=dict(title='DRS'))

fig.show()
# Out:
# <div>                            <div id="6c9ce797-cc6c-464a-99aa-f54b89327afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c9ce797-cc6c-464a-99aa-f54b89327afb")) {                    Plotly.newPlot(                        "6c9ce797-cc6c-464a-99aa-f54b89327afb",                        [{"hovertemplate":"nome_drs=Campinas<br>ano_mes=%{x}<br>casos_novos=%{y}<extra></extra>","legendgroup":"Campinas","line":{"color":"yellow","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Campinas","orientation":"v","showlegend":true,"x":["2020-02","2020-03","2020-04","2020-05","2020-06"],"xaxis":"x","y":[0,27,927,4041,952],"yaxis":"y","type":"scatter"},{"hovertemplate":"nome_drs=Mar\u00edlia<br>ano_mes=%{x}<br>casos_novos=%{y}<extra></e
# ...

# %% [markdown]
# **c)** Considerando apenas os DRS 'Bauru', 'São José do Rio Preto' e 'Marília', faça três gráficos de pizza, para os meses de abril, maio e junho, mostrando a porcentagem de novos óbitos em cada DRS.

# %%
df2_3_drs = df2[['ano_mes','nome_drs','obitos_novos']][(df2['nome_drs'] == 'Bauru') | (df2['nome_drs'] == 'São José do Rio Preto'
                                              ) | (df2['nome_drs'] == 'Marília')]

# %%
df2_aux = df2_3_drs.groupby(by = ['ano_mes','nome_drs'], as_index=False).sum()

# %%
df2_aux[df2_aux['ano_mes'] == '2020-04']
# Out:
#    ano_mes               nome_drs  obitos_novos
# 6  2020-04                  Bauru            26
# 7  2020-04                Marília             9
# 8  2020-04  São José do Rio Preto            12

# %%
px.pie(names='nome_drs', values='obitos_novos', data_frame=df2_aux[df2_aux['ano_mes'] == '2020-04'], 
       hole=0.2, title='Óbitos Novos no Mês de Abril')
# Out:
# <div>                            <div id="7295f733-1906-4871-aea8-f0adfa1a17d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7295f733-1906-4871-aea8-f0adfa1a17d6")) {                    Plotly.newPlot(                        "7295f733-1906-4871-aea8-f0adfa1a17d6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"nome_drs=%{label}<br>obitos_novos=%{value}<extra></extra>","labels":["Bauru","Mar\u00edlia","S\u00e3o Jos\u00e9 do Rio Preto"],"legendgroup":"","name":"","showlegend":true,"values":[26,9,12],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"
# ...

# %%
px.pie(names='nome_drs', values='obitos_novos', data_frame=df2_aux[df2_aux['ano_mes'] == '2020-05'], 
       hole=0.2, title='Óbitos Novos no Mês de Maio')
# Out:
# <div>                            <div id="28531eb5-d31a-4a15-97d6-ba6b8135b192" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28531eb5-d31a-4a15-97d6-ba6b8135b192")) {                    Plotly.newPlot(                        "28531eb5-d31a-4a15-97d6-ba6b8135b192",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"nome_drs=%{label}<br>obitos_novos=%{value}<extra></extra>","labels":["Bauru","Mar\u00edlia","S\u00e3o Jos\u00e9 do Rio Preto"],"legendgroup":"","name":"","showlegend":true,"values":[49,14,45],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay
# ...

# %%
px.pie(names='nome_drs', values='obitos_novos', data_frame=df2_aux[df2_aux['ano_mes'] == '2020-06'], 
       hole=0.2, title='Óbitos Novos no Mês de Junho')
# Out:
# <div>                            <div id="fcc02bcf-5ff2-48b5-b3f8-0d5ce275f4ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcc02bcf-5ff2-48b5-b3f8-0d5ce275f4ae")) {                    Plotly.newPlot(                        "fcc02bcf-5ff2-48b5-b3f8-0d5ce275f4ae",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.2,"hovertemplate":"nome_drs=%{label}<br>obitos_novos=%{value}<extra></extra>","labels":["Bauru","Mar\u00edlia","S\u00e3o Jos\u00e9 do Rio Preto"],"legendgroup":"","name":"","showlegend":true,"values":[4,2,9],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","
# ...

# %% [markdown]
# ## Exercício 3:
# Utilizando a base de dados de covid e a biblioteca plotly:
#
# **a)** Faça um gráfico de barras mostrando o total de óbitos (considerando todos os meses) para todos os DRS, excluindo a Grande São Paulo. Coloque título no gráfico e nos eixos, defina um tamanho de imagem bom e intercale as barras com as cores 'red' e 'green'.

# %%
df2_3_drs = df2[['ano_mes','nome_drs','obitos_novos']][(df2['nome_drs'] == 'Bauru') | (df2['nome_drs'] == 'São José do Rio Preto'
                                              ) | (df2['nome_drs'] == 'Marília')]

# %%
df2_sem_sampa = df2[df2['nome_drs'] != 'Grande São Paulo']

# %%
df2_aux = df2_sem_sampa.groupby(by = 'nome_drs', as_index=False).sum()

# %%
df2_aux
# Out:
#                  nome_drs  codigo_ibge  cod_drs         pop     pop_60  \
# 0              Araraquara    423373300    960.0   4957175.0   816440.0
# 1               Araçatuba    704712425   1400.0   3820205.0   674945.0
# 2        Baixada Santista    158849420    585.0   9159420.0  1488380.0
# 3                Barretos    317754110   1440.0   2125450.0   365450.0
# 4                   Bauru   1198170110   4080.0   8706405.0  1435905.0
# 5                Campinas    741036525    630.0  22810625.0  3455290.0
# 6                  Franca    388245000    440.0   3481680.0   546295.0
# 7                 Marília   1093775455   1550.0   5548350.0  1004680.0
# 8              Piracicaba    458447635   1430.0   7698000.0  1223405.0
# 9     Presidente Prudente    794734555    450.0   3761300.0   666735.0
# 10               Registro    264365135    675.0   1393770.0   220460.0
# 11         Ribeirão Preto    458864555    130.0   7387650.0  1145615.0
# ...

# %%
px.bar(x='nome_drs', y='obitos', data_frame=df2_aux, color='nome_drs', color_discrete_sequence=['red','green'])

fig.update_xaxes(title=None)
fig.update_yaxes(title='Total de Óbitos ')

fig.update_layout(legend=dict(title='DRS')) # ??? como retirar essa legenda enorme?
# Out:
# <div>                            <div id="3c5ea6e1-f553-4743-b65b-9ae2fa91da2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c5ea6e1-f553-4743-b65b-9ae2fa91da2f")) {                    Plotly.newPlot(                        "3c5ea6e1-f553-4743-b65b-9ae2fa91da2f",                        [{"alignmentgroup":"True","hovertemplate":"nome_drs=%{x}<br>obitos=%{y}<extra></extra>","legendgroup":"Araraquara","marker":{"color":"red","pattern":{"shape":""}},"name":"Araraquara","offsetgroup":"Araraquara","orientation":"v","showlegend":true,"textposition":"auto","x":["Araraquara"],"xaxis":"x","y":[518],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nome_drs=%{x}<br>obitos=%{y}<extra></extra>","legendgroup":"Ara\u00e7atuba","marker":{"colo
# ...

# %% [markdown]
# **b)**  Faça um gráfico de barras horizontal mostrando o total de óbitos no mês de abril para 3 DRS da sua escolha. Coloque título no gráfico e nos eixos, defina um tamanho de imagem bom.

# %%
df2_abr = df2[((df2['ano_mes'] == '2020-04')) &
              ((df2['nome_drs'] == 'Campinas') | (df2['nome_drs'] == 'Araraquara') | (df2['nome_drs'] == 'Piracicaba'))]
df2_abr.head()
# Out:
#               nome_munic  codigo_ibge    nome_drs  cod_drs       pop   pop_60  \
# 57             Americana      3501608    Campinas      3.0  233458.0  40276.0
# 62                Amparo      3501905    Campinas      3.0   69639.0  12727.0
# 67   Américo Brasiliense      3501707  Araraquara      8.0   40243.0   4465.0
# 77             Analândia      3502002  Piracicaba     11.0    4850.0    813.0
# 132           Araraquara      3503208  Araraquara      8.0  227618.0  40188.0
#
#      ano_mes  casos  casos_novos  obitos  obitos_novos
# 57   2020-04    520           49      68             3
# 62   2020-04    103            9       0             0
# 67   2020-04     77            7       0             0
# 77   2020-04      0            0       0             0
# 132  2020-04    815           72      46             3

# %%
fig = px.bar(x='obitos', y='nome_drs', data_frame=df2_abr, color='nome_drs', orientation='h')

fig.update_yaxes(title=None)
fig.update_xaxes(title='Total de Óbitos ')

fig.update_layout(legend=dict(title='DRS'))

fig.show()
# Out:
# <div>                            <div id="7e1c3bc1-4f67-46db-9e63-6b16ca088508" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e1c3bc1-4f67-46db-9e63-6b16ca088508")) {                    Plotly.newPlot(                        "7e1c3bc1-4f67-46db-9e63-6b16ca088508",                        [{"alignmentgroup":"True","hovertemplate":"nome_drs=%{y}<br>obitos=%{x}<extra></extra>","legendgroup":"Campinas","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Campinas","offsetgroup":"Campinas","orientation":"h","showlegend":true,"textposition":"auto","x":[68,0,0,16,0,152,0,211,20,0,0,7,28,24,8,0,7,0,148,0,0,0,5,0,6,13,7,0,0,0,6,13,0,0,0,2,0,43,0,12,18,23],"xaxis":"x","y":["Campinas","Campinas","Campinas","Campinas","Campinas","Campinas","Campinas","
# ...

# %% [markdown]
# ## Exercício 4:
#
# **a)** Utilizando a base de dados da IBM e a biblioteca plotly, crie um histograma para as idades dos funcionários, separando por gênero.

# %%
fig = px.histogram(x='Age',data_frame=df1, color='Gender', opacity=0.7)

fig.update_yaxes(title='Contagem para Idades')
fig.update_xaxes(title='Idades')

fig.update_layout(legend=dict(title='Gênero'))

fig.show()
# Out:
# <div>                            <div id="da900352-cd44-4fcc-9f80-622611fa7ff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da900352-cd44-4fcc-9f80-622611fa7ff5")) {                    Plotly.newPlot(                        "da900352-cd44-4fcc-9f80-622611fa7ff5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=Female<br>Age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"x":[41,33,59,29,29,53,24,34,53,32,44,46,43,35,36,33,27,30,41,44,26,33,35,38,50,59,36,55,59,36,31,38,30,54,24,20,34,59,50,22,51,54,34,34,36,36,56,26,58,49,43,50,31,26,39,32,38,30,30,19,40,32
# ...

# %% [markdown]
# **b)** Faça agora um boxplot das idades, por gênero.

# %%
fig = px.box(x='Gender', y='Age', data_frame=df1, color='Gender')

fig.update_yaxes(title='Contagem para Idades')
fig.update_xaxes(title='Gênero')

fig.update_layout(legend=dict(title='Gênero'))

fig.show()
# Out:
# <div>                            <div id="ed996d8f-9fca-480a-9679-38f8359a053e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed996d8f-9fca-480a-9679-38f8359a053e")) {                    Plotly.newPlot(                        "ed996d8f-9fca-480a-9679-38f8359a053e",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}<br>Age=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa"},"name":"Female","notched":false,"offsetgroup":"Female","orientation":"v","showlegend":true,"x":["Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Fe
# ...
